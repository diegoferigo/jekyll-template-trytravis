# %% [markdown]
# # This is a title

# %%
print("I'm python code!! With output")
# Out:
# I'm python code!! With output

# %% [markdown]
# And latex equations:
# \begin{equation}
#     y = A x
# \end{equation}

# %%
# Normal Distribution
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(np.random.normal(size=100000), bins=30)
plt.show()
